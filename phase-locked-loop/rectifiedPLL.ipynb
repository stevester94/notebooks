# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This shit works. Need to make sample rate configurable in the PLL



# Yes, this one is immediate in the original
class PhaseDetector:
    def __init__(self) -> None:
        pass

    def proc( self, sigIn, sigOut ):
        return sigIn * sigOut

# Yes, this one is immediate in the original
class LoopFilter:
    def __init__( self, K_i, K_p ) -> None:
        self.K_i = K_i
        self.K_p = K_p
        self.integrator = 0
    
    def proc( self, e_D ):
        self.integrator += self.K_i * e_D / fs # Still unsure on this but I think it's right
        
        return self.K_p * e_D + self.integrator

    

class NumericallyControlledOscillator:
    def __init__( self, K_0, f, fs ) -> None:
        self.K_0 = K_0
        self.f = f
        self.fs = fs
        self.theta = 0
        
        first = True
        
        self.nextPhaseEstimate = 0
        self.nextCosOut = 1
        self.nextSinOut = 0

    def proc( self, e_F ):
        phaseEstimate = self.nextPhaseEstimate
        
        self.theta += 2*np.pi*self.f/self.fs
        if self.theta > 2*np.pi:
            self.theta -= 2*np.pi

            
        ret = (self.nextCosOut, self.nextSinOut)
        
        self.nextPhaseEstimate = phaseEstimate + self.K_0 * e_F
        self.nextCosOut = np.cos( self.theta + phaseEstimate )
        self.nextSinOut = -np.sin( self.theta + phaseEstimate )
                
        return ret
    

class PhaseLockedLoop:
    def __init__( self, K_i, K_p, K_0, pll_f, fs ) -> None:
        self.pd = PhaseDetector()
        self.lf = LoopFilter( K_i, K_p )
        self.nco = NumericallyControlledOscillator( K_0, pll_f, fs )

        self.last_sin_out = 0
        self.last_cos_out = 1


    """
    The original code for this seemed pretty interested in delaying the output by one sample (or something along those lines)
    I took that all out and it appears to still work fine
    """
    def proc( self, in_, ):
        _e_D = self.pd.proc( in_, self.nco.nextSinOut )

        #loop filter
        _e_F = self.lf.proc( _e_D )

        _cos_out, _sin_out  = self.nco.proc(_e_F)
        
        self.last_sin_out = _sin_out
        self.last_cos_out = _cos_out
        
        ret = (self.last_cos_out, self.last_sin_out, _e_D)

        return ret

K_p = 0.2667
K_i = 0.0178
K_0 = 1

fs = 1
duration_secs = 100
t = np.linspace(0,duration_secs, int(duration_secs*fs))
t = np.arange( duration_secs*fs )

in_A      = 1
in_f_Hz   = fs/15 # Make it equivalent to original
# in_phi    = np.random.normal(0, 0.0, size=len(t)) + np.pi
in_phi    = np.pi
in_sig    = in_A * np.cos( 2*np.pi * in_f_Hz * t + in_phi )
# in_sig    += np.random.normal(0, 0.0, size=len(t)) # AWGN

e_D = [] #phase-error output
cos_out = []



pll = PhaseLockedLoop( K_i, K_p, K_0, in_f_Hz, fs )
for n in range(len(t)):
    _cos_out, _sin_out, _e_D = pll.proc( in_sig[n] )
    
    cos_out.append( _cos_out )
    e_D.append( _e_D )



# Create a Figure
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(20)

# Set up Axes
ax1 = fig.add_subplot(211)
ax1.plot(cos_out, label='PLL Output')
plt.grid()
ax1.plot(in_sig, label='Input Signal')
plt.legend()
ax1.set_title('Waveforms')

# Show the plot
#plt.show()

ax2 = fig.add_subplot(212)
ax2.plot( e_D )
plt.grid()
ax2.set_title('Filtered Error')
plt.show()

# %%
# OK, what does the phase detector do?

fs = 100
duration_secs = 2
t = np.linspace(0,duration_secs, int(duration_secs*fs))

a = 2.0 * np.sin( 2*np.pi * 4*t )
b = 2.0 * np.sin( 2*np.pi * 4*t )

pd = PhaseDetector()

phase = []
for i in range(len(a)):
    phase.append( pd.proc( a[i], b[i] ) )

    # Create a Figure
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(20)

ax1 = fig.add_subplot(111)
ax1.plot(a, label='signal a', alpha=0.25 )
ax1.plot(b, label='signal b', alpha=0.25 )
ax1.plot(phase, label='Phase Delta')
plt.grid()
plt.legend()
ax1.set_title('Waveforms')
# Out:
# Text(0.5, 1.0, 'Waveforms')

# %%
# OK what does the loop filter do?
# OK, what does the phase detector do?

class LoopFilter:
    def __init__( self, K_i, K_p ) -> None:
        self.K_i = K_i
        self.K_p = K_p
        self.integrator = 0
    
    def proc( self, e_D ):
        self.integrator += (self.K_i * e_D) / (1.0*fs)
#         return self.integrator
        return self.K_p * e_D + self.integrator

K_p = 0.025
K_i = 5
# K_i = 1.0

fs = 5000
duration_secs = 5
t = np.linspace(0,duration_secs, int(duration_secs*fs))

a = 1.0 * np.sin( 2*np.pi * 1*t )
b = 1.00 * np.sin( 2*np.pi * 50*t )
s = a+b

pd = PhaseDetector()
lf = LoopFilter( K_i, K_p )

phase = []
filtered = []
for i in range(len(a)):
    filtered.append ( lf.proc( s[i] ) )
    # Create a Figure
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(20)

ax2 = fig.add_subplot(211)
ax2.plot(s, label='Sum')
ax2.plot(filtered, label='Filtered')
plt.grid()
plt.legend()
ax2.set_title('Waveforms')
# Out:
# Text(0.5, 1.0, 'Waveforms')
